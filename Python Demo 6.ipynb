# %% [markdown]
# # <center>Pandas Demo 6</center>
# <img src="img/pandas.jpg" width="250" height="250" />

# %% [markdown]
# ### We have successfully completed the first segment of todays lecture  Now for the second part
# # Sorting Data
#
# <img src="img/sort.jpeg" width="250" height="250" />

# %%
import pandas as pd
df = pd.read_csv('developer_survey_2019/survey_results_public.csv')
pd.set_option('max_rows',8,'max_columns',14)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
#                    OpenSourcer  \
# 0                        Never
# 1      Less than once per year
# 2                        Never
# 3                        Never
# ...

# %% [markdown]
# ### Let's call our trusty mini_df
#
# <img src="img/call.jpg" width="250" height="250" />

# %%
mini_df=df.loc[0:7,['Age','Country','Gender','Student']]

# %%
mini_df
# Out:
#     Age                 Country Gender         Student
# 0  14.0          United Kingdom    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 2  28.0                Thailand    Man              No
# 3  22.0           United States    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 6  42.0                 Ukraine    Man              No
# 7  24.0                   India    Man             NaN

# %% [markdown]
# ### Let's start sorting

# %%
mini_df.sort_values(by='Age')
# Out:
#     Age                 Country Gender         Student
# 0  14.0          United Kingdom    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 3  22.0           United States    Man              No
# 7  24.0                   India    Man             NaN
# 2  28.0                Thailand    Man              No
# 5  28.0                  Canada    Man              No
# 4  30.0                 Ukraine    Man              No
# 6  42.0                 Ukraine    Man              No

# %%
mini_df.sort_values(by='Age',ascending=False)
# Out:
#     Age                 Country Gender         Student
# 6  42.0                 Ukraine    Man              No
# 4  30.0                 Ukraine    Man              No
# 2  28.0                Thailand    Man              No
# 5  28.0                  Canada    Man              No
# 7  24.0                   India    Man             NaN
# 3  22.0           United States    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 0  14.0          United Kingdom    Man              No

# %% [markdown]
# ### Now we will sort using two arguments. First argument has higher priority.

# %%
mini_df.sort_values(by=['Age','Country'])
# Out:
#     Age                 Country Gender         Student
# 0  14.0          United Kingdom    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 3  22.0           United States    Man              No
# 7  24.0                   India    Man             NaN
# 5  28.0                  Canada    Man              No
# 2  28.0                Thailand    Man              No
# 4  30.0                 Ukraine    Man              No
# 6  42.0                 Ukraine    Man              No

# %% [markdown]
# ### The sorting order for both the arguments may not be same

# %%
mini_df.sort_values(by=['Age','Country'], ascending=[False,True])
# Out:
#     Age                 Country Gender         Student
# 6  42.0                 Ukraine    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 2  28.0                Thailand    Man              No
# 7  24.0                   India    Man             NaN
# 3  22.0           United States    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 0  14.0          United Kingdom    Man              No

# %%
mini_df
# Out:
#     Age                 Country Gender         Student
# 0  14.0          United Kingdom    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 2  28.0                Thailand    Man              No
# 3  22.0           United States    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 6  42.0                 Ukraine    Man              No
# 7  24.0                   India    Man             NaN

# %%
mini_df.sort_values(by=['Age','Country'], ascending=[False,True],inplace=True)

# %%
mini_df
# Out:
#     Age                 Country Gender         Student
# 6  42.0                 Ukraine    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 2  28.0                Thailand    Man              No
# 7  24.0                   India    Man             NaN
# 3  22.0           United States    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 0  14.0          United Kingdom    Man              No

# %% [markdown]
# ### We have sorted our data.... But ... Something went wrong.... We want the original unsorted data back......What are we gonna do
#
#
# <img src="img/panic.png" width="250" height="250" />
#
#
#
# ### We will just sort the index column. Simple.

# %%
mini_df.sort_index()
# Out:
#     Age                 Country Gender         Student
# 0  14.0          United Kingdom    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 2  28.0                Thailand    Man              No
# 3  22.0           United States    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 6  42.0                 Ukraine    Man              No
# 7  24.0                   India    Man             NaN

# %%
mini_df
# Out:
#     Age                 Country Gender         Student
# 6  42.0                 Ukraine    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 2  28.0                Thailand    Man              No
# 7  24.0                   India    Man             NaN
# 3  22.0           United States    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 0  14.0          United Kingdom    Man              No

# %%
mini_df.sort_index(inplace=True)

# %%
mini_df
# Out:
#     Age                 Country Gender         Student
# 0  14.0          United Kingdom    Man              No
# 1  19.0  Bosnia and Herzegovina    Man  Yes, full-time
# 2  28.0                Thailand    Man              No
# 3  22.0           United States    Man              No
# 4  30.0                 Ukraine    Man              No
# 5  28.0                  Canada    Man              No
# 6  42.0                 Ukraine    Man              No
# 7  24.0                   India    Man             NaN

# %% [markdown]
# ### Here is how we can sort a specific column

# %%
mini_df['Age'].sort_values()
# Out:
# 0    14.0
# 1    19.0
# 3    22.0
# 7    24.0
# 2    28.0
# 5    28.0
# 4    30.0
# 6    42.0
# Name: Age, dtype: float64

# %% [markdown]
# ### Using nlargest function, we can ..... Well never mind ...It is obvious what we can do with it

# %%
df['Age'].nlargest(10)
# Out:
# 9792     99.0
# 11279    99.0
# 11495    99.0
# 16126    99.0
#          ...
# 27680    99.0
# 29707    99.0
# 34757    99.0
# 36089    99.0
# Name: Age, Length: 10, dtype: float64

# %% [markdown]
# ### If we want the complete dataframe sorted according to a column ...

# %%
df.nlargest(10,'Age')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 9792         9833             I am a student who is learning to code      Yes
# 11279       11332                     I am a developer by profession       No
# 11495       11548             I am a student who is learning to code       No
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 27680       27841                     I am a developer by profession      Yes
# 29707       29884                     I am a developer by profession      Yes
# 34757       34973  I used to be a developer by profession, but no...       No
# 36089       36312                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 9792                             Less than once per year
# 11279  Less than once a month but more than once per ...
# ...

# %% [markdown]
# ### Similarly, we have nsmallest as well

# %%
df['Age'].nsmallest(12)
# Out:
# 719      1.0
# 9613     1.0
# 11799    1.0
# 11887    1.0
#         ...
# 41250    1.0
# 62752    1.0
# 64067    1.0
# 67762    1.0
# Name: Age, Length: 12, dtype: float64

# %% [markdown]
# # That's All Folks
#
#
# <img src="img/bugs.png" width="150" height="150" />
